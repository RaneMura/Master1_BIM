# %% [markdown]
# ## TME 5 : RÉSEAUX

# %% [markdown]
# #### 3. Degree distribution

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
reseau1 = np.genfromtxt('reseau1.txt', delimiter=",")
reseau2 = np.genfromtxt('reseau2.txt', delimiter=",")
reseau3 = np.loadtxt('reseau3.txt', delimiter=",",dtype=str)

# %%
def distr(reseau):
    return np.unique(reseau,return_counts = True)

# %%
uniq = distr(reseau1)
uniq2 = distr(reseau2)
uniq3 = distr(reseau3)

# %% [markdown]
# 2. Pour savoir si le reseau est scale free ou aléatoire

# %%
#Tracé de la distribution 
#mattre des points
plt.scatter(uniq[0],uniq[1],label = "distr1")
plt.scatter(uniq2[0],uniq2[1],label = "distr2")
plt.legend()

plt.show()

# %%
plt.scatter(uniq3[0],uniq3[1],label="distr3")
plt.show()

# %% [markdown]
# 4. Un réseau scale free est un réseau qui suit une loi de puissance P(k) = k pow(-gamma) (2<gamma<3)

# %% [markdown]
# La 1 est scale-free car y a de la dissipation
# La 2 est aléatoire ca ry a convergence vers 20

# %% [markdown]
# #### 4. Clustering coefficent

# %% [markdown]
# cc(A) = 2*0/(10*9) = 0
# cc(B) = 2*4/(10*9) = 4/45
# cc(C) = 2*2/(10*9) = 2/45
# cc(D) = 2*1/(3*2) = 1/3
# cc(E) = 2*6/(10*9) = 2/15

# %%
noeuds = np.unique(reseau1)
sortie = []
for noeud in noeuds:
    sortie.append[noeud]
    sortie[noeud] = np.argwhere(reseau1==noeud)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [88], in <cell line: 3>()
#       2 sortie = []
#       3 for noeud in noeuds:
# ----> 4     sortie.append[noeud]
#       5     sortie[noeud] = np.argwhere(reseau1==noeud)
#
# TypeError: 'builtin_function_or_method' object is not subscriptable

# %%
def cc(reseau,noeud):
# Out:
#   Input In [80]
#     def cc(reseau,noeud):
#                          ^
# SyntaxError: incomplete input
